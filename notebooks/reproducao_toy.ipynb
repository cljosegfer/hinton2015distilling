# %% [markdown]
# # setup

# %%
import os

if os.getcwd().split('/')[-1] == 'notebooks':
    os.chdir('..')

# %%
import torch

# %%
from runners.toy import BaselineRunner

# %% [markdown]
# # init

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # baseline

# %%
runner = BaselineRunner(device = device, depth = 0)
runner.run()
# Out:
# 100%|██████████| 200/200 [00:12<00:00, 16.09it/s]
# 0.012321230471134186 0.011934815466403962 5.006048045793755e-06
# 0.795 0.82

# %%
runner = BaselineRunner(device = device, depth = 1)
runner.run()
# Out:
# 100%|██████████| 200/200 [00:15<00:00, 13.06it/s]
# 0.009547407776117324 0.008806128114461898 1.1069213188521745e-07
# 0.885 0.882

# %%
runner = BaselineRunner(device = device, depth = 2)
runner.run()
# Out:
# 100%|██████████| 200/200 [00:17<00:00, 11.17it/s]
# 0.004858126491308212 0.003663577638566494 2.8360413782340604e-08
# 0.9325 0.945

# %%
runner = BaselineRunner(device = device, depth = 3)
runner.run()
# Out:
# 100%|██████████| 200/200 [00:20<00:00,  9.79it/s]
# 0.005173620264977217 0.0038331896513700485 1.7617221664699575e-08
# 0.9525 0.944

# %%
runner = BaselineRunner(device = device, depth = 4)
runner.run()
# Out:
# 100%|██████████| 200/200 [00:22<00:00,  8.77it/s]
# 0.002333518825471401 0.0022875130604952574 2.169104468584414e-08
# 0.9675 0.965

# %%
runner = BaselineRunner(device = device, depth = 5)
runner.run()
# Out:
# 100%|██████████| 200/200 [00:25<00:00,  7.78it/s]
# 0.003128611594438553 0.002341459273840883 1.2212245048301737e-08
# 0.955 0.976

# %%
runner = BaselineRunner(device = device, depth = 6)
runner.run()
# Out:
# 100%|██████████| 200/200 [00:27<00:00,  7.14it/s]
# 0.0076575628668069835 0.004383167251944542 0.0004116972591145895
# 0.92 0.932

# %%
runner = BaselineRunner(device = device, depth = 7)
runner.run()
# Out:
# 100%|██████████| 200/200 [00:30<00:00,  6.55it/s]
# 0.00856092631816864 0.006477589249610901 0.0006174669484607876
# 0.895 0.9
